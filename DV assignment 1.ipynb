# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('canteen_shop_data.csv')
df
# Out:
#            Date   Time      Item  Price  Quantity  Total  Customer ID  \
# 0    2024-04-01  12:15  Sandwich    4.5         2    9.0            1
# 1    2024-04-01  12:30     Drink    1.5         1    1.5            2
# 2    2024-04-01  12:45     Salad    5.0         1    5.0            3
# 3    2024-04-01  13:00    Burger    5.5         1    5.5            4
# 4    2024-04-01  13:15  Sandwich    4.5         1    4.5            5
# ..          ...    ...       ...    ...       ...    ...          ...
# 195  2024-04-25  12:45    Burger    5.5         2   11.0          196
# 196  2024-04-25  13:00  Sandwich    4.5         1    4.5          197
# 197  2024-04-25  13:15     Drink    1.5         1    1.5          198
# 198  2024-04-25  13:30     Salad    5.0         2   10.0          199
# 199  2024-04-25  13:45    Burger    5.5         1    5.5          200
#
#      Payment Method  Employee ID  Customer Satisfaction Weather Special Offers
# ...

# %%
sns.scatterplot(data=df, x='Employee ID', y='Payment Method')
plt.title('Employee ID vs Payment Method')
plt.show()

# %%
sns.histplot(data=df, x='Weather', bins=20, kde=True)
plt.title('Weather	')
plt.show()
# Out:
# C:\Users\91908\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.boxplot(data=df, x='Customer Satisfaction', y='Special Offers')
plt.title('customer satisfaction by special offer')
plt.show()

# %%
sns.violinplot(data=df, x='Customer Satisfaction', y='Special Offers')
plt.title('customer satisfaction')
plt.show()

# %%
sns.barplot(data=df, x='Customer ID', y='Price', estimator=np.mean)
plt.title('customer id and price')
plt.show()

# %%
sns.pairplot(df[['Total', 'Employee ID','Customer Satisfaction','Quantity' ]])
plt.title('Pairplot')
plt.show()
